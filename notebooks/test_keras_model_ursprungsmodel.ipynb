# %% [markdown]
# ### Bildvorverarbeitung

# %%
import cv2
import numpy as np
from pathlib import Path
from dataclasses import dataclass
import random
import shutil

@dataclass
class QRROIConfig:
    patch_size: int = 256
    max_slidingwindow_size: int = 1280
    overlap: float = 0.75
    min_area: int = 500
    top_k: int = 50
    debug_view: bool = True

def pad_and_crop(img, cx, cy, size):
    half = size // 2
    x0, y0 = cx - half, cy - half
    x1, y1 = x0 + size, y0 + size
    h, w = img.shape[:2]
    
    pad_top = max(0, -y0); pad_bottom = max(0, y1 - h)
    pad_left = max(0, -x0); pad_right = max(0, x1 - w)
    
    if any([pad_top, pad_bottom, pad_left, pad_right]):
        img = cv2.copyMakeBorder(img, pad_top, pad_bottom, pad_left, pad_right, cv2.BORDER_CONSTANT, value=[0,0,0])
        x0 += pad_left; x1 += pad_left; y0 += pad_top; y1 += pad_top
        
    patch = img[y0:y1, x0:x1]
    return patch

def generate_patches(img, cand, cfg: QRROIConfig):
    patches_data = [] 
    S = cfg.patch_size
    
    if cand["w"] <= S and cand["h"] <= S:
        p = pad_and_crop(img, cand["cx"], cand["cy"], S)
        patches_data.append((p, cand["cx"] - S//2, cand["cy"] - S//2, S))
    else:   
        W = cfg.max_slidingwindow_size
        actual_S = S
        if not(cand["w"] <= W and cand["h"] <= W):
            max_size = max(cand["w"], cand["h"])
            actual_S = int(np.ceil(max_size / 5))

        stride = max(1, int(actual_S * (1 - cfg.overlap)))
        for y_s in range(cand["y"], cand["y"] + cand["h"] - actual_S + stride, stride):
            for x_s in range(cand["x"], cand["x"] + cand["w"] - actual_S + stride, stride):
                ax = min(x_s, cand["x"] + cand["w"] - actual_S)
                ay = min(y_s, cand["y"] + cand["h"] - actual_S)
                
                cx_patch = ax + actual_S // 2
                cy_patch = ay + actual_S // 2

                patch = pad_and_crop(img, cx_patch, cy_patch, actual_S)
                if actual_S != 256:
                    patch = cv2.resize(patch, (256, 256), interpolation=cv2.INTER_AREA)

                patches_data.append((patch, ax, ay, actual_S))
    return patches_data

def detect_candidates(img, cfg: QRROIConfig):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    avg_brightness = np.mean(gray)
    thresh_val = 100 if avg_brightness < 70 else 180
    
    _, mask = cv2.threshold(gray, thresh_val, 255, cv2.THRESH_BINARY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (25, 25))
    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    contours, _ = cv2.findContours(closed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    candidates = []
    for cnt in contours:
        if cv2.contourArea(cnt) < cfg.min_area: continue
        x, y, w, h = cv2.boundingRect(cnt)
        candidates.append({
            "cx": x + w // 2, "cy": y + h // 2, 
            "x": x, "y": y, "w": w, "h": h, 
            "score": cv2.contourArea(cnt)
        })
    return sorted(candidates, key=lambda x: x["score"], reverse=True)[:cfg.top_k]

def main():
    # --- Verzeichnisse ---
    input_dir = Path("~/DatenUbuntu/Studium/1. Semester/KI-Projekt/modeltest/pictures").expanduser()
    test_picture_dir = Path("test_picture")
    output_root = Path("test_patches")
    
    cfg = QRROIConfig()

    # Ordner erstellen
    test_picture_dir.mkdir(parents=True, exist_ok=True)
    out_patches_root = output_root / "patches"
    out_patches_root.mkdir(parents=True, exist_ok=True)

    if not input_dir.exists():
        print(f"❌ Quelle '{input_dir}' existiert nicht.")
        return

    img_files = [f for f in input_dir.iterdir() if f.suffix.lower() in [".jpg", ".jpeg", ".png"]]
    
    if not img_files:
        print(f"❌ Keine Bilder gefunden.")
        return

    # --- Random Auswahl ---
    try:
        user_input = input(f"Anzahl Bilder aus '{len(img_files)}' wählen? ('all' oder Zahl): ")
        if user_input.lower() == 'all':
            num_to_process = len(img_files)
        else:
            num_to_process = min(int(user_input), len(img_files))
    except ValueError:
        num_to_process = 1

    selected_files = random.sample(img_files, num_to_process)
    patch_metadata = []

    print(f"🚀 Verarbeite {num_to_process} Bilder...")

    for img_file in selected_files:
        # 1. In test_picture kopieren
        shutil.copy2(img_file, test_picture_dir / img_file.name)

        # 2. Analyse
        img = cv2.imread(str(img_file))
        if img is None: continue
        h_orig, w_orig = img.shape[:2]
        
        img_patch_dir = out_patches_root / img_file.stem
        img_patch_dir.mkdir(parents=True, exist_ok=True)
        
        candidates = detect_candidates(img, cfg)
        vis_img = img.copy()

        for i, cand in enumerate(candidates):
            roi_data = generate_patches(img, cand, cfg)
            
            for p_idx, (patch, px, py, ps) in enumerate(roi_data):
                patch_name = f"roi{i:02d}_p{p_idx:02d}.jpg"
                cv2.imwrite(str(img_patch_dir / patch_name), patch)
                
                rel_path = f"{img_file.stem}/{patch_name}"
                patch_metadata.append(f"{img_file.name};{rel_path};{px};{py};{ps};{w_orig};{h_orig}")
                
                # Visualisierung: Gelbe Patches
                cv2.rectangle(vis_img, (px, py), (px + ps, py + ps), (0, 255, 255), 1)

            # Visualisierung: Grüne Kandidaten-ROI
            cv2.rectangle(vis_img, (cand["x"], cand["y"]), (cand["x"] + cand["w"], cand["y"] + cand["h"]), (0, 255, 0), 3)

        # 3. Visualisierung anzeigen (läuft automatisch durch)
        if cfg.debug_view:
            scale = 800 / max(h_orig, w_orig)
            res_small = cv2.resize(vis_img, None, fx=scale, fy=scale)
            cv2.imshow("Analyse-Vorschau (Auto-Run)", res_small)
            # 100ms warten, wenn 'q' gedrückt wird, abbrechen
            if cv2.waitKey(100) & 0xFF == ord('q'): 
                break

    # Metadaten speichern
    with open(output_root / "metadata.txt", "w") as f:
        f.write("\n".join(patch_metadata))
    
    cv2.destroyAllWindows()
    print(f"\n✅ Abgeschlossen. Bilder in '{test_picture_dir}', Patches in '{output_root}'.")

if __name__ == "__main__":
    main()
# Out:
# 🚀 Verarbeite 100 Bilder...
#
# ✅ Abgeschlossen. Bilder in 'test_picture', Patches in 'test_patches'.

# %% [markdown]
# ### Modelldurchlauf

# %%
import os

# 1. System-Konfiguration (Unterdrückt Warnungen und behebt Berechtigungsprobleme)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
os.environ['MPLCONFIGDIR'] = os.path.join(os.getcwd(), "tmp_matplotlib_cache")
if not os.path.exists(os.environ['MPLCONFIGDIR']):
    os.makedirs(os.environ['MPLCONFIGDIR'], exist_ok=True)

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from ipywidgets import interact, IntSlider

# 2. Pfade und Parameter (Basierend auf deiner Struktur)
model_path = 'final_model.keras'
folder_path = 'test_patches/patches'
img_size = (256, 256)

# 3. Modell laden
try:
    model = load_model(model_path)
    print(f"✅ Modell '{model_path}' erfolgreich geladen.")
except Exception as e:
    print(f"❌ Fehler beim Laden des Modells: {e}")
    model = None

# 4. Bilder-Liste erstellen
if os.path.exists(folder_path):
    files = sorted([str(p.relative_to(folder_path)) for p in Path(folder_path).rglob('*') 
                    if p.suffix.lower() in ('.png', '.jpg', '.jpeg', '.tif')])
    print(f"🔍 {len(files)} Bilder in Unterordnern von '{folder_path}' gefunden.")
else:
    print(f"❌ Ordner '{folder_path}' wurde nicht gefunden!")
    files = []

# 5. Anzeige-Funktion für den Slider
def browse_patches(index):
    if not files:
        print("Keine Bilder vorhanden.")
        return

    filename = files[index]
    img_path = os.path.join(folder_path, filename)
    
    # Bild laden (Grayscale + 256x256)
    img = load_img(img_path, target_size=img_size, color_mode='grayscale')
    img_array = img_to_array(img)
    
    img_tensor = np.expand_dims(img_array, axis=0)

    # Vorhersage
    prediction = model.predict(img_tensor, verbose=0)
    
    # Bestimmung der Wahrscheinlichkeit für Klasse 1
    if prediction.shape[-1] == 1:
        prob_1 = float(prediction[0][0])
    else:
        prob_1 = float(prediction[0][1])
    
    label = 1 if prob_1 > 0.5 else 0
    color = 'green' if label == 1 else 'red'

    # Visualisierung
    plt.figure(figsize=(6, 6))
    plt.imshow(img_array.squeeze(), cmap='gray')
    
    title_str = (f"Bild {index+1}/{len(files)}: {filename}\n"
                 f"KLASSE: {label} | Wahrsch. Klasse 1: {prob_1:.4f}")
    
    plt.title(title_str, color=color, fontsize=12, fontweight='bold')
    plt.axis('off')
    plt.show()

# 6. Interaktives Element starten
if files and model:
    print("Nutze den Slider oder die Pfeiltasten deiner Tastatur zum Durchblättern:")
    interact(browse_patches, index=IntSlider(
        min=0, 
        max=len(files)-1, 
        step=1, 
        value=0, 
        description='Patch-Index:',
        layout={'width': '500px'}
    ))
# Out:
# /home/marlon/DatenUbuntu/Github/KI-Projekt/KI-Project-WS2526/.venv/lib/python3.13/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767906277.331604  114135 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4081 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# ✅ Modell 'final_model.keras' erfolgreich geladen.
# 🔍 16914 Bilder in Unterordnern von 'test_patches/patches' gefunden.
# Nutze den Slider oder die Pfeiltasten deiner Tastatur zum Durchblättern:
# interactive(children=(IntSlider(value=0, description='Patch-Index:', layout=Layout(width='500px'), max=16913),…

# %%
import cv2
import numpy as np
import os
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.models import load_model

# --- 1. GPU & System Setup (Robust) ---
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['MPLCONFIGDIR'] = str(Path.home() / ".matplotlib_cache")
Path(os.environ['MPLCONFIGDIR']).mkdir(exist_ok=True)

def setup_gpu():
    try:
        gpus = tf.config.list_physical_devices('GPU')
        if gpus:
            for gpu in gpus:
                if not tf.config.experimental.get_memory_growth(gpu):
                    tf.config.experimental.set_memory_growth(gpu, True)
            print(f"✅ GPU Beschleunigung aktiv.")
    except RuntimeError:
        print("ℹ️ GPU bereits initialisiert.")
setup_gpu()

# --- 2. Konfiguration ---
class QRFinalConfig:
    model_path = 'final_model.keras'
    base_path = Path('test_patches')
    patch_folder = base_path / "patches"
    metadata_file = base_path / "metadata.txt"
    original_img_dir = Path('test_picture')
    output_dir = Path('final_results')
    
    threshold = 0.85      # Dein Schwellenwert (0.0 bis 1.0)
    batch_size = 32       # Reduziert auf 32 für stabilen VRAM

# --- 3. Die kombinierte Pipeline (Pfad A Fokus) ---
def run_combined_pipeline():
    cfg = QRFinalConfig()
    cfg.output_dir.mkdir(exist_ok=True)
    
    if not cfg.metadata_file.exists():
        print("❌ Metadaten-Datei nicht gefunden!")
        return

    model = load_model(cfg.model_path)
    
    with open(cfg.metadata_file, "r") as f:
        lines = [l.strip().split(";") for l in f.readlines()]

    images_dict = {}
    for img_name, rel_path, px, py, ps, w_orig, h_orig in lines:
        if img_name not in images_dict:
            images_dict[img_name] = {"w": int(w_orig), "h": int(h_orig), "patches": []}
        images_dict[img_name]["patches"].append({"path": rel_path, "x": int(px), "y": int(py), "s": int(ps)})

    print(f"--- Analyse startet (Pfad A: Ungefilterte Detektion) ---")

    for img_name, info in images_dict.items():
        orig_img = cv2.imread(str(cfg.original_img_dir / img_name))
        if orig_img is None: continue
        h_orig, w_orig = info["h"], info["w"]
        
        # --- BATCH LOADING (Skalierung 0-255 wie beim Training) ---
        patch_list = info["patches"]
        all_patch_imgs = []
        for p in patch_list:
            p_img = cv2.imread(str(cfg.patch_folder / p["path"]), cv2.IMREAD_GRAYSCALE)
            if p_img is None: continue
            p_img = cv2.resize(p_img, (256, 256), interpolation=cv2.INTER_LINEAR)
            all_patch_imgs.append(p_img.astype(np.float32)) # KEINE Division durch 255!

        # Vorhersage
        input_batch = np.expand_dims(np.array(all_patch_imgs), axis=-1)
        preds = model.predict(input_batch, batch_size=cfg.batch_size, verbose=0)
        
        # --- HEATMAP REKONSTRUKTION (MAX-LOGIK) ---
        heatmap_max = np.zeros((h_orig, w_orig), dtype=np.float32)
        
        max_prob = 0.0
        for i, prob_vec in enumerate(preds):
            prob = float(prob_vec[0]) if len(prob_vec) == 1 else float(prob_vec[1])
            max_prob = max(max_prob, prob)
            
            p = patch_list[i]
            x, y, s = p["x"], p["y"], p["s"]
            # Max-Pooling: Der stärkste Patch gewinnt pro Pixel
            heatmap_max[y:y+s, x:x+s] = np.maximum(heatmap_max[y:y+s, x:x+s], prob)

        # ==========================================================
        # PFAD A: DETEKTION AUF DEN ROHDATEN (KEIN FILTER!)
        # ==========================================================
        # Wir suchen die Rahmen direkt auf heatmap_max (Werte 0.0 bis 1.0)
        _, thresh = cv2.threshold(heatmap_max, cfg.threshold, 1.0, cv2.THRESH_BINARY)
        thresh_8bit = (thresh * 255).astype(np.uint8)
        
        # Konturen finden (Das sind jetzt die exakten Rahmen der Treffer-Patches)
        contours, _ = cv2.findContours(thresh_8bit, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # ==========================================================
        # PFAD B: VISUALISIERUNG (NUR FÜR DIE OPTIK)
        # ==========================================================
        heatmap_8bit = (heatmap_max * 255).astype(np.uint8)
        # Blur wird NUR für die Farbanzeige verwendet
        heatmap_vis = cv2.GaussianBlur(heatmap_8bit, (15, 15), 0)
        heatmap_color = cv2.applyColorMap(heatmap_vis, cv2.COLORMAP_JET)
        overlay = cv2.addWeighted(orig_img, 0.6, heatmap_color, 0.4, 0)
        
        # Zeichne die Rahmen aus Pfad A in das Overlay
        found_count = 0
        for cnt in contours:
            x, y, w, h = cv2.boundingRect(cnt)
            # Kleiner Noise-Filter (nur Flächen größer als 15x15 px umrahmen)
            if w > 15 and h > 15:
                cv2.rectangle(overlay, (x, y), (x + w, y + h), (0, 255, 0), 4)
                found_count += 1

        # --- INFO BANNER ---
        status = "QR GEFUNDEN" if max_prob >= cfg.threshold else "KEIN TREFFER"
        cv2.rectangle(overlay, (0, 0), (overlay.shape[1], 60), (0, 0, 0), -1)
        cv2.putText(overlay, f"{status} | Max Prob: {max_prob:.1%} | Objs: {found_count}", 
                    (20, 42), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 255, 255), 3)

        cv2.imwrite(str(cfg.output_dir / f"final_{img_name}"), overlay)
        print(f"✅ {img_name}: {status} ({max_prob:.2%})")

if __name__ == "__main__":
    run_combined_pipeline()
# Out:
# ℹ️ GPU bereits initialisiert.
# --- Analyse startet (Pfad A: Ungefilterte Detektion) ---
# ✅ 20251129_155426.jpg: QR GEFUNDEN (100.00%)
# ✅ IMG_7468.JPEG: KEIN TREFFER (82.50%)
# ✅ GKLASSE_NEU_P1_frame4170.jpg: KEIN TREFFER (35.81%)
# ✅ IMG_6914.jpg: QR GEFUNDEN (91.68%)
# ✅ Passat_P3_frame1260.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N3_frame2960.jpg: KEIN TREFFER (3.66%)
# ✅ 20251213_125143_027.jpg: QR GEFUNDEN (100.00%)
# ✅ 20251213_125053_083.jpg: QR GEFUNDEN (100.00%)
# ✅ CKlasse_Bilderreihe 4_P_IMG_9631_rot4.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P1_frame2060.jpg: QR GEFUNDEN (100.00%)
# ✅ IMG_6754.jpg: QR GEFUNDEN (99.87%)
# ✅ Passat_N1_frame230.jpg: KEIN TREFFER (27.37%)
# ✅ Golf_VI_P_63.jpg: QR GEFUNDEN (100.00%)
# ✅ 20251129_155630.jpg: KEIN TREFFER (29.52%)
# ✅ Passat_P3_frame750.jpg: QR GEFUNDEN (100.00%)
# ✅ 20251124_141712.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N2_frame2020.jpg: KEIN TREFFER (56.38%)
# ✅ Focus_P1_frame_260.jpg: QR GEFUNDEN (100.00%)
# ✅ CKlasse_Bilderreihe 2_P_IMG_9439_rot13.jpg: QR GEFUNDEN (100.00%)
# ✅ IMG_6842.jpg: KEIN TREFFER (61.25%)
# ✅ Passat_N1_frame1190.jpg: KEIN TREFFER (11.10%)
# ✅ CKlasse_Bilderreihe 4_P_IMG_9645_rot-7.jpg: KEIN TREFFER (2.43%)
# ✅ Passat_P2_frame2410.jpg: QR GEFUNDEN (99.30%)
# ✅ Focus_P2_frame_2620.jpg: QR GEFUNDEN (100.00%)
# ✅ CKlasse_Bilderreihe 5_P_IMG_9511_rot0.jpg: QR GEFUNDEN (100.00%)
# ✅ GKLASSE_ALT_P1_frame1460.jpg: QR GEFUNDEN (100.00%)
# ✅ GKLASSE_NEU_P1_frame3490.jpg: KEIN TREFFER (22.38%)
# ✅ GKLASSE_ALT_P1_frame140.jpg: QR GEFUNDEN (100.00%)
# ✅ Focus_P2_frame_2240.jpg: KEIN TREFFER (58.67%)
# ✅ Seat_N_15.jpg: QR GEFUNDEN (99.53%)
# ✅ Passat_P1_frame2520.jpg: QR GEFUNDEN (100.00%)
# ✅ Focus_P2_frame_2370.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N2_frame260.jpg: KEIN TREFFER (43.31%)
# ✅ Passat_P3_frame2300.jpg: QR GEFUNDEN (98.17%)
# ✅ FocusP3_frame_3730.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N2_frame3010.jpg: KEIN TREFFER (35.62%)
# ✅ Golf_IV_P_34.jpg: QR GEFUNDEN (85.40%)
# ✅ CKlasse_Bilderreihe 4_P_IMG_9624_dark.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N2_frame850.jpg: KEIN TREFFER (21.44%)
# ✅ Focus_P2_frame_3130.jpg: QR GEFUNDEN (100.00%)
# ✅ IMG_7464.JPEG: QR GEFUNDEN (100.00%)
# ✅ Focus_P2_frame_2730.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P1_frame560.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N3_frame2430.jpg: KEIN TREFFER (23.11%)
# ✅ Passat_P1_frame40.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P2_frame80.jpg: QR GEFUNDEN (100.00%)
# ✅ Seat_N_26.jpg: KEIN TREFFER (9.58%)
# ✅ GKLASSE_ALT_P1_frame740.jpg: QR GEFUNDEN (100.00%)
# ✅ IMG_7457.JPEG: QR GEFUNDEN (100.00%)
# ✅ CKlasse_Bilderreihe 2_P_IMG_9440_contrast.jpg: QR GEFUNDEN (100.00%)
# ✅ Golf_IV_N_49.jpg: KEIN TREFFER (66.05%)
# ✅ Seat_P_13.jpg: QR GEFUNDEN (100.00%)
# ✅ CKlasse_Bilderreihe 4_P_IMG_9613_rot13.jpg: QR GEFUNDEN (100.00%)
# ✅ 20251213_125053_055.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P1_frame1990.jpg: QR GEFUNDEN (100.00%)
# ✅ Seat_N_19.jpg: KEIN TREFFER (18.24%)
# ✅ Focus_P2_frame_1450.jpg: QR GEFUNDEN (100.00%)
# ✅ GKLASSE_NEU_P1_frame3280.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P1_frame1370.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P3_frame1760.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P3_frame2040.jpg: KEIN TREFFER (25.31%)
# ✅ FocusP4_frame_2250.jpg: QR GEFUNDEN (98.11%)
# ✅ Passat_P1_frame1140.jpg: KEIN TREFFER (82.93%)
# ✅ Focus_P2_frame_3220.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N2_frame980.jpg: KEIN TREFFER (38.51%)
# ✅ Passat_P1_frame990.jpg: QR GEFUNDEN (100.00%)
# ✅ CKlasse_Bilderreihe 2_P_IMG_9400_rot4.jpg: QR GEFUNDEN (100.00%)
# ✅ FocusP3_frame_1220.jpg: QR GEFUNDEN (100.00%)
# ✅ CKlasse_Bilderreihe 3_P_IMG_9566_rot-6.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P3_frame1980.jpg: KEIN TREFFER (29.71%)
# ✅ Focus_P1_frame_610.jpg: QR GEFUNDEN (100.00%)
# ✅ Focus_P2_frame_2850.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N1_frame740.jpg: KEIN TREFFER (33.66%)
# ✅ 20251213_125100_003.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N1_frame1600.jpg: KEIN TREFFER (10.90%)
# ✅ CKlasse_Bilderreihe 2_P_IMG_9412_rot-14.jpg: QR GEFUNDEN (100.00%)
# ✅ FocusP4_frame_2090.jpg: QR GEFUNDEN (100.00%)
# ✅ CKlasse_Bilderreihe 3_P_IMG_9543_contrast.jpg: QR GEFUNDEN (100.00%)
# ✅ FocusP3_frame_2130.jpg: QR GEFUNDEN (100.00%)
# ✅ Golf_VI_P_26.jpg: QR GEFUNDEN (100.00%)
# ✅ Golf_IV_N_47.jpg: KEIN TREFFER (36.07%)
# ✅ Passat_P3_frame210.jpg: QR GEFUNDEN (100.00%)
# ✅ FocusP4_frame_2760.jpg: QR GEFUNDEN (100.00%)
# ✅ GKLASSE_ALT_P1_frame1270.jpg: QR GEFUNDEN (100.00%)
# ✅ 20251129_155335.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N3_frame60.jpg: KEIN TREFFER (14.29%)
# ✅ GKLASSE_ALT_P1_frame950.jpg: QR GEFUNDEN (100.00%)
# ✅ Focus_P2_frame_250.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P1_frame2300.jpg: QR GEFUNDEN (99.62%)
# ✅ GKLASSE_ALT_P1_frame3460.jpg: QR GEFUNDEN (100.00%)
# ✅ FocusP3_frame_150.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P3_frame780.jpg: QR GEFUNDEN (100.00%)
# ✅ IMG_6843.jpg: QR GEFUNDEN (100.00%)
# ✅ GKLASSE_NEU_P1_frame810.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_N2_frame2550.jpg: KEIN TREFFER (29.17%)
# ✅ FocusP3_frame_2730.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P3_frame1250.jpg: QR GEFUNDEN (100.00%)
# ✅ IMG_6672.jpg: KEIN TREFFER (61.11%)
# ✅ CKlasse_Bilderreihe 3_P_IMG_9554_bright.jpg: QR GEFUNDEN (100.00%)
# ✅ Passat_P3_frame3210.jpg: QR GEFUNDEN (100.00%)

# %% [markdown]
# ### Heatmap

# %%
import cv2
import numpy as np
import os
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.models import load_model

# --- 1. Robustes GPU-Setup ---
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def setup_gpu():
    try:
        gpus = tf.config.list_physical_devices('GPU')
        if gpus:
            for gpu in gpus:
                if not tf.config.experimental.get_memory_growth(gpu):
                    tf.config.experimental.set_memory_growth(gpu, True)
            print(f"✅ GPU (RTX 4050) für Heatmap-Erstellung bereit.")
    except RuntimeError:
        print("ℹ️ GPU war bereits initialisiert. Fahre fort...")

setup_gpu()

# --- 2. Konfiguration ---
class HeatmapConfig:
    model_path = 'final_model.keras'
    base_path = Path('test_patches')
    patch_folder = base_path / "patches"
    metadata_file = base_path / "metadata.txt"
    output_folder = Path('heatmaps_output')
    
    batch_size = 32  # Passt gut in den 6GB VRAM der RTX 4050

# --- 3. Hauptfunktion ---
def generate_gpu_heatmaps():
    cfg = HeatmapConfig()
    cfg.output_folder.mkdir(exist_ok=True)

    if not cfg.metadata_file.exists():
        print(f"❌ {cfg.metadata_file} nicht gefunden!")
        return

    # Modell laden
    print("⏳ Lade Modell...")
    model = load_model(cfg.model_path)

    # Metadaten einlesen
    with open(cfg.metadata_file, "r") as f:
        data_lines = [line.strip().split(";") for line in f.readlines()]

    # Gruppierung nach Originalbild
    images_dict = {}
    for img_name, rel_patch_path, px, py, ps, w_orig, h_orig in data_lines:
        if img_name not in images_dict:
            images_dict[img_name] = {"w": int(w_orig), "h": int(h_orig), "patches": []}
        images_dict[img_name]["patches"].append({
            "rel_path": rel_patch_path, "x": int(px), "y": int(py), "s": int(ps)
        })

    print(f"--- Starte Heatmap-Generierung für {len(images_dict)} Bilder ---")

    for img_name, info in images_dict.items():
        h, w = info["h"], info["w"]
        # Initialisierung mit Nullen
        heatmap_max = np.zeros((h, w), dtype=np.float32)

        print(f"🚀 Verarbeite: {img_name}")

        # --- BATCH LOADING ---
        patch_list = info["patches"]
        all_patch_imgs = []
        
        for p in patch_list:
            # Schnelles Laden via OpenCV (Graustufen, 0-255 Scale)
            p_img = cv2.imread(str(cfg.patch_folder / p["rel_path"]), cv2.IMREAD_GRAYSCALE)
            if p_img is None: continue
            p_img = cv2.resize(p_img, (256, 256))
            all_patch_imgs.append(p_img.astype(np.float32))

        if not all_patch_imgs:
            continue

        # In Tensor-Format umwandeln (Batch, Height, Width, Channels)
        input_batch = np.expand_dims(np.array(all_patch_imgs), axis=-1)

        # --- GPU INFERENCE ---
        # Alle Patches des Bildes in einem Rutsch vorhersagen
        preds = model.predict(input_batch, batch_size=cfg.batch_size, verbose=0)

        # --- REKONSTRUKTION ---
        for i, prob_vec in enumerate(preds):
            prob = float(prob_vec[0]) if len(prob_vec) == 1 else float(prob_vec[1])
            
            p = patch_list[i]
            px, py, ps = p["x"], p["y"], p["s"]
            
            # Maximum-Logik (Pfad A): Der höchste Wert pro Pixel gewinnt
            # Das verhindert das "Verwässern" durch schlechte Patches
            heatmap_max[py:py+ps, px:px+ps] = np.maximum(heatmap_max[py:py+ps, px:px+ps], prob)

        # --- SPEICHERN ---
        # Umwandlung in 8-Bit Grayscale
        heatmap_8bit = (heatmap_max * 255).astype(np.uint8)
        
        # Optional: Falls du eine farbige Heatmap willst, aktiviere die nächste Zeile:
        # heatmap_8bit = cv2.applyColorMap(heatmap_8bit, cv2.COLORMAP_JET)

        output_path = cfg.output_folder / f"{Path(img_name).stem}_heatmap.png"
        cv2.imwrite(str(output_path), heatmap_8bit)

    print(f"✅ Alle Heatmaps wurden in '{cfg.output_folder}' erstellt.")

# --- Startbefehl ---
if __name__ == "__main__":
    generate_gpu_heatmaps()
# Out:
# ℹ️ GPU war bereits initialisiert. Fahre fort...
# ⏳ Lade Modell...
# --- Starte Heatmap-Generierung für 100 Bilder ---
# 🚀 Verarbeite: 20251129_155426.jpg
# 🚀 Verarbeite: IMG_7468.JPEG
# 🚀 Verarbeite: GKLASSE_NEU_P1_frame4170.jpg
# 🚀 Verarbeite: IMG_6914.jpg
# 🚀 Verarbeite: Passat_P3_frame1260.jpg
# 🚀 Verarbeite: Passat_N3_frame2960.jpg
# 🚀 Verarbeite: 20251213_125143_027.jpg
# 🚀 Verarbeite: 20251213_125053_083.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 4_P_IMG_9631_rot4.jpg
# 🚀 Verarbeite: Passat_P1_frame2060.jpg
# 🚀 Verarbeite: IMG_6754.jpg
# 🚀 Verarbeite: Passat_N1_frame230.jpg
# 🚀 Verarbeite: Golf_VI_P_63.jpg
# 🚀 Verarbeite: 20251129_155630.jpg
# 🚀 Verarbeite: Passat_P3_frame750.jpg
# 🚀 Verarbeite: 20251124_141712.jpg
# 🚀 Verarbeite: Passat_N2_frame2020.jpg
# 🚀 Verarbeite: Focus_P1_frame_260.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 2_P_IMG_9439_rot13.jpg
# 🚀 Verarbeite: IMG_6842.jpg
# 🚀 Verarbeite: Passat_N1_frame1190.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 4_P_IMG_9645_rot-7.jpg
# 🚀 Verarbeite: Passat_P2_frame2410.jpg
# 🚀 Verarbeite: Focus_P2_frame_2620.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 5_P_IMG_9511_rot0.jpg
# 🚀 Verarbeite: GKLASSE_ALT_P1_frame1460.jpg
# 🚀 Verarbeite: GKLASSE_NEU_P1_frame3490.jpg
# 🚀 Verarbeite: GKLASSE_ALT_P1_frame140.jpg
# 🚀 Verarbeite: Focus_P2_frame_2240.jpg
# 🚀 Verarbeite: Seat_N_15.jpg
# 🚀 Verarbeite: Passat_P1_frame2520.jpg
# 🚀 Verarbeite: Focus_P2_frame_2370.jpg
# 🚀 Verarbeite: Passat_N2_frame260.jpg
# 🚀 Verarbeite: Passat_P3_frame2300.jpg
# 🚀 Verarbeite: FocusP3_frame_3730.jpg
# 🚀 Verarbeite: Passat_N2_frame3010.jpg
# 🚀 Verarbeite: Golf_IV_P_34.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 4_P_IMG_9624_dark.jpg
# 🚀 Verarbeite: Passat_N2_frame850.jpg
# 🚀 Verarbeite: Focus_P2_frame_3130.jpg
# 🚀 Verarbeite: IMG_7464.JPEG
# 🚀 Verarbeite: Focus_P2_frame_2730.jpg
# 🚀 Verarbeite: Passat_P1_frame560.jpg
# 🚀 Verarbeite: Passat_N3_frame2430.jpg
# 🚀 Verarbeite: Passat_P1_frame40.jpg
# 🚀 Verarbeite: Passat_P2_frame80.jpg
# 🚀 Verarbeite: Seat_N_26.jpg
# 🚀 Verarbeite: GKLASSE_ALT_P1_frame740.jpg
# 🚀 Verarbeite: IMG_7457.JPEG
# 🚀 Verarbeite: CKlasse_Bilderreihe 2_P_IMG_9440_contrast.jpg
# 🚀 Verarbeite: Golf_IV_N_49.jpg
# 🚀 Verarbeite: Seat_P_13.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 4_P_IMG_9613_rot13.jpg
# 🚀 Verarbeite: 20251213_125053_055.jpg
# 🚀 Verarbeite: Passat_P1_frame1990.jpg
# 🚀 Verarbeite: Seat_N_19.jpg
# 🚀 Verarbeite: Focus_P2_frame_1450.jpg
# 🚀 Verarbeite: GKLASSE_NEU_P1_frame3280.jpg
# 🚀 Verarbeite: Passat_P1_frame1370.jpg
# 🚀 Verarbeite: Passat_P3_frame1760.jpg
# 🚀 Verarbeite: Passat_P3_frame2040.jpg
# 🚀 Verarbeite: FocusP4_frame_2250.jpg
# 🚀 Verarbeite: Passat_P1_frame1140.jpg
# 🚀 Verarbeite: Focus_P2_frame_3220.jpg
# 🚀 Verarbeite: Passat_N2_frame980.jpg
# 🚀 Verarbeite: Passat_P1_frame990.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 2_P_IMG_9400_rot4.jpg
# 🚀 Verarbeite: FocusP3_frame_1220.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 3_P_IMG_9566_rot-6.jpg
# 🚀 Verarbeite: Passat_P3_frame1980.jpg
# 🚀 Verarbeite: Focus_P1_frame_610.jpg
# 🚀 Verarbeite: Focus_P2_frame_2850.jpg
# 🚀 Verarbeite: Passat_N1_frame740.jpg
# 🚀 Verarbeite: 20251213_125100_003.jpg
# 🚀 Verarbeite: Passat_N1_frame1600.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 2_P_IMG_9412_rot-14.jpg
# 🚀 Verarbeite: FocusP4_frame_2090.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 3_P_IMG_9543_contrast.jpg
# 🚀 Verarbeite: FocusP3_frame_2130.jpg
# 🚀 Verarbeite: Golf_VI_P_26.jpg
# 🚀 Verarbeite: Golf_IV_N_47.jpg
# 🚀 Verarbeite: Passat_P3_frame210.jpg
# 🚀 Verarbeite: FocusP4_frame_2760.jpg
# 🚀 Verarbeite: GKLASSE_ALT_P1_frame1270.jpg
# 🚀 Verarbeite: 20251129_155335.jpg
# 🚀 Verarbeite: Passat_N3_frame60.jpg
# 🚀 Verarbeite: GKLASSE_ALT_P1_frame950.jpg
# 🚀 Verarbeite: Focus_P2_frame_250.jpg
# 🚀 Verarbeite: Passat_P1_frame2300.jpg
# 🚀 Verarbeite: GKLASSE_ALT_P1_frame3460.jpg
# 🚀 Verarbeite: FocusP3_frame_150.jpg
# 🚀 Verarbeite: Passat_P3_frame780.jpg
# 🚀 Verarbeite: IMG_6843.jpg
# 🚀 Verarbeite: GKLASSE_NEU_P1_frame810.jpg
# 🚀 Verarbeite: Passat_N2_frame2550.jpg
# 🚀 Verarbeite: FocusP3_frame_2730.jpg
# 🚀 Verarbeite: Passat_P3_frame1250.jpg
# 🚀 Verarbeite: IMG_6672.jpg
# 🚀 Verarbeite: CKlasse_Bilderreihe 3_P_IMG_9554_bright.jpg
# 🚀 Verarbeite: Passat_P3_frame3210.jpg
# ✅ Alle Heatmaps wurden in 'heatmaps_output' erstellt.

# %% [markdown]
# ### Visualisierung

# %%
import cv2
import numpy as np
from pathlib import Path

# --- 1. Konfiguration der Pfade ---
path_original = Path('test_picture')
path_heatmap = Path('heatmaps_output')
path_decision = Path('final_results')

# --- 2. FIXE FENSTERGRÖSSE ---
WINDOW_WIDTH = 1500
WINDOW_HEIGHT = 500

def show_interactive_evaluation():
    # Bilder suchen
    img_files = sorted(list(path_original.glob("*.[jJ][pP][gG]")) + list(path_original.glob("*.[pP][nN][gG]")))
    
    if not img_files:
        print("❌ Keine Originalbilder gefunden.")
        return

    single_w = WINDOW_WIDTH // 3
    single_h = WINDOW_HEIGHT

    # --- COUNTER INITIALISIEREN ---
    stats = {
        "richtig": 0,
        "falsch": 0,
        "gesamt": 0
    }

    print(f"--- Interaktive Evaluation gestartet ---")
    print("Steuerung: [J] = Richtig erkannt | [N] = Falsch erkannt | [Q] = Beenden")

    for idx, img_file in enumerate(img_files):
        stem = img_file.stem
        
        # 1. Bilder laden
        img_orig = cv2.imread(str(img_file))
        
        # Heatmap suchen (verschiedene Endungen)
        heatmap_path = next((p for p in [path_heatmap / f"{stem}_heatmap.png", path_heatmap / f"{stem}_heatmap.jpg"] if p.exists()), None)
        img_heat = cv2.imread(str(heatmap_path)) if heatmap_path else None
        
        # Ergebnis suchen
        final_path = next((p for p in [path_decision / f"final_{img_file.name}", path_decision / f"result_{img_file.name}"] if p.exists()), None)
        img_final = cv2.imread(str(final_path)) if final_path else None

        # Falls ein Teil fehlt, überspringen
        if img_orig is None or img_heat is None or img_final is None:
            continue

        # 2. Resizing
        res_orig = cv2.resize(img_orig, (single_w, single_h), interpolation=cv2.INTER_AREA)
        res_heat = cv2.resize(img_heat, (single_w, single_h), interpolation=cv2.INTER_AREA)
        res_final = cv2.resize(img_final, (single_w, single_h), interpolation=cv2.INTER_AREA)

        # 3. Farbraum-Check
        if len(res_heat.shape) == 2:
            res_heat = cv2.cvtColor(res_heat, cv2.COLOR_GRAY2BGR)

        # 4. Horizontal stapeln
        triple_view = np.hstack((res_orig, res_heat, res_final))

        # 5. Beschriftungen (Header)
        header_text = [("ORIGINAL", 10), ("HEATMAP", single_w + 10), ("DETEKTION", (single_w * 2) + 10)]
        for text, pos_x in header_text:
            cv2.putText(triple_view, text, (pos_x + 2, 32), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 0), 2)
            cv2.putText(triple_view, text, (pos_x, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

        # 6. Status-Leiste (Footer)
        # Balken unten für bessere Lesbarkeit
        cv2.rectangle(triple_view, (0, single_h - 40), (WINDOW_WIDTH, single_h), (50, 50, 50), -1)
        
        status_str = f"Bild {idx+1}/{len(img_files)} | Richtig: {stats['richtig']} | Falsch: {stats['falsch']} | DRUECKE: [J]a / [N]ein"
        cv2.putText(triple_view, status_str, (20, single_h - 12), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

        # 7. Anzeige & Interaktions-Loop
        cv2.imshow("QR-Analyse Evaluation", triple_view)
        
        valid_key = False
        while not valid_key:
            key = cv2.waitKey(0) & 0xFF
            
            if key == ord('q'):
                print("\n🛑 Abbruch durch Benutzer.")
                print_summary(stats)
                cv2.destroyAllWindows()
                return

            elif key == ord('j'): # Ja / Richtig
                stats["richtig"] += 1
                stats["gesamt"] += 1
                print(f"✅ Bild {idx+1}: Richtig markiert.")
                valid_key = True

            elif key == ord('n'): # Nein / Falsch
                stats["falsch"] += 1
                stats["gesamt"] += 1
                print(f"❌ Bild {idx+1}: Falsch markiert.")
                valid_key = True
            
            else:
                print("⚠️  Bitte 'j' für Richtig, 'n' für Falsch oder 'q' zum Beenden drücken.")

    print_summary(stats)
    cv2.destroyAllWindows()

def print_summary(stats):
    total = stats["gesamt"]
    if total == 0:
        print("Keine Bilder bewertet.")
        return
        
    acc = (stats["richtig"] / total) * 100
    print("\n" + "="*40)
    print(f"📊 ABSCHLUSSBERICHT")
    print("="*40)
    print(f"Gesamt bewertet: {total}")
    print(f"✅ Richtig:       {stats['richtig']}")
    print(f"❌ Falsch:        {stats['falsch']}")
    print("-" * 40)
    print(f"📈 Genauigkeit:   {acc:.2f}%")
    print("="*40)

if __name__ == "__main__":
    show_interactive_evaluation()
# Out:
# --- Interaktive Evaluation gestartet ---
# Steuerung: [J] = Richtig erkannt | [N] = Falsch erkannt | [Q] = Beenden
# ✅ Bild 1: Richtig markiert.
# ✅ Bild 3: Richtig markiert.
# ✅ Bild 4: Richtig markiert.
# ❌ Bild 5: Falsch markiert.
# ✅ Bild 6: Richtig markiert.
# ✅ Bild 7: Richtig markiert.
# ✅ Bild 8: Richtig markiert.
# ✅ Bild 9: Richtig markiert.
# ✅ Bild 11: Richtig markiert.
# ✅ Bild 12: Richtig markiert.
# ✅ Bild 13: Richtig markiert.
# ✅ Bild 14: Richtig markiert.
# ✅ Bild 15: Richtig markiert.
# ✅ Bild 16: Richtig markiert.
# ✅ Bild 18: Richtig markiert.
# ✅ Bild 19: Richtig markiert.
# ✅ Bild 20: Richtig markiert.
# ✅ Bild 21: Richtig markiert.
# ❌ Bild 23: Falsch markiert.
# ✅ Bild 24: Richtig markiert.
# ✅ Bild 25: Richtig markiert.
# ✅ Bild 26: Richtig markiert.
# ✅ Bild 27: Richtig markiert.
# ✅ Bild 28: Richtig markiert.
# ✅ Bild 29: Richtig markiert.
# ✅ Bild 31: Richtig markiert.
# ✅ Bild 32: Richtig markiert.
# ✅ Bild 33: Richtig markiert.
# ✅ Bild 35: Richtig markiert.
# ✅ Bild 37: Richtig markiert.
# ✅ Bild 38: Richtig markiert.
# ❌ Bild 39: Falsch markiert.
# ✅ Bild 40: Richtig markiert.
# ✅ Bild 41: Richtig markiert.
# ✅ Bild 42: Richtig markiert.
# ✅ Bild 43: Richtig markiert.
# ✅ Bild 44: Richtig markiert.
# ✅ Bild 45: Richtig markiert.
# ✅ Bild 46: Richtig markiert.
# ✅ Bild 48: Richtig markiert.
# ✅ Bild 49: Richtig markiert.
# ✅ Bild 50: Richtig markiert.
# ✅ Bild 51: Richtig markiert.
# ✅ Bild 52: Richtig markiert.
# ✅ Bild 53: Richtig markiert.
# ✅ Bild 55: Richtig markiert.
# ❌ Bild 56: Falsch markiert.
# ❌ Bild 57: Falsch markiert.
# ✅ Bild 58: Richtig markiert.
# ❌ Bild 59: Falsch markiert.
# ❌ Bild 60: Falsch markiert.
# ✅ Bild 62: Richtig markiert.
# ✅ Bild 64: Richtig markiert.
# ✅ Bild 65: Richtig markiert.
# ❌ Bild 66: Falsch markiert.
# ❌ Bild 67: Falsch markiert.
# ❌ Bild 68: Falsch markiert.
# ✅ Bild 69: Richtig markiert.
# ✅ Bild 70: Richtig markiert.
# ❌ Bild 71: Falsch markiert.
# ❌ Bild 72: Falsch markiert.
# ❌ Bild 73: Falsch markiert.
# ❌ Bild 76: Falsch markiert.
# ❌ Bild 77: Falsch markiert.
# ❌ Bild 79: Falsch markiert.
# ❌ Bild 80: Falsch markiert.
# ❌ Bild 81: Falsch markiert.
# ❌ Bild 82: Falsch markiert.
# ❌ Bild 83: Falsch markiert.
# ❌ Bild 84: Falsch markiert.
# ❌ Bild 86: Falsch markiert.
# ❌ Bild 87: Falsch markiert.
# ❌ Bild 88: Falsch markiert.
# ✅ Bild 89: Richtig markiert.
# ✅ Bild 90: Richtig markiert.
# ✅ Bild 91: Richtig markiert.
# ✅ Bild 92: Richtig markiert.
# ✅ Bild 93: Richtig markiert.
# ✅ Bild 94: Richtig markiert.
# ✅ Bild 95: Richtig markiert.
# ✅ Bild 96: Richtig markiert.
# ✅ Bild 97: Richtig markiert.
# ✅ Bild 98: Richtig markiert.
# ✅ Bild 99: Richtig markiert.
# ✅ Bild 100: Richtig markiert.
# ✅ Bild 101: Richtig markiert.
# ❌ Bild 102: Falsch markiert.
# ❌ Bild 103: Falsch markiert.
# ✅ Bild 104: Richtig markiert.
# ✅ Bild 105: Richtig markiert.
# ✅ Bild 106: Richtig markiert.
# ✅ Bild 107: Richtig markiert.
# ✅ Bild 108: Richtig markiert.
# ❌ Bild 110: Falsch markiert.
# ❌ Bild 111: Falsch markiert.
# ❌ Bild 112: Falsch markiert.
# ✅ Bild 114: Richtig markiert.
#
# ========================================
# 📊 ABSCHLUSSBERICHT
# ========================================
# Gesamt bewertet: 97
# ✅ Richtig:       68
# ❌ Falsch:        29
# ----------------------------------------
# 📈 Genauigkeit:   70.10%
# ========================================
